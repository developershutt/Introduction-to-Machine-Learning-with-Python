# %% [markdown]
# # Search over spaces that are not grids
#
# In some cases, trying all possible combinations of all parameters as GridSearchCV usually does, is not a good idea. For example, SVC has a kernel parameter, and depending on which kernel is chosen, other parameters will be relevant. If ker nel='linear', the model is linear, and only the C parameter is used. If kernel='rbf', both the C and gamma parameters are used (but not other parameters like degree). In this case, searching over all possible combinations of C, gamma, and kernel wouldn’t make sense: if kernel='linear', gamma is not used, and trying different values for gamma would be a waste of time. To deal with these kinds of “conditional” parameters, GridSearchCV allows the param_grid to be a list of dictionaries. Each dictionary in the list is expanded into an independent grid. A possible grid search involving kernel and parameters could look like this:

# %%
param_grid = [{'kernel': ['rbf'],
               'C': [0.001, 0.01, 0.1, 1, 10, 100], 
               'gamma': [0.001, 0.01, 0.1, 1, 10, 100]},
              {'kernel': ['linear'],'C': [0.001, 0.01, 0.1, 1, 10, 100]}] 
print("List of grids:\n{}".format(param_grid))
# Out:
# List of grids:
# [{'kernel': ['rbf'], 'C': [0.001, 0.01, 0.1, 1, 10, 100], 'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}, {'kernel': ['linear'], 'C': [0.001, 0.01, 0.1, 1, 10, 100]}]

# %% [markdown]
# In the first grid, the kernel parameter is always set to 'rbf' (not that the entry for kernel is a list of length one), and both the C and gamma parameters are varied. In the second grid, the kernel parameter is always set to linear, and only C is varied. Now let’s apply this more complex parameter search:

# %%
from sklearn.svm import SVC
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import numpy as np
import mglearn
import pandas as pd

iris=load_iris()
X_train,X_test,y_train,y_test=train_test_split(iris.data,iris.target,random_state=0)
X_train,X_val,y_train,y_val=train_test_split(X_train,y_train,random_state=0)

# %%
grid_search=GridSearchCV(SVC(),param_grid=param_grid,cv=5)
grid_search.fit(X_train,y_train)
print("Best parameters: {}".format(grid_search.best_params_))
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
# Out:
# Best parameters: {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# Best cross-validation score: 0.99

# %%
# Let’s look at the cv_results_ again. As expected, if kernel is 'linear', then only C is varied:

results=pd.DataFrame(grid_search.cv_results_)
# we display the tranposed table so that it better fits on the page
display(results.T)
# Out:
# c:\users\deepblue\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# c:\users\deepblue\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# c:\users\deepblue\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# c:\users\deepblue\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# c:\users\deepblue\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# c:\users\deepblue\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# c:\users\deepblue\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#                                                                0   \
# mean_fit_time                                         0.000997639
# std_fit_time                                          6.14362e-07
# mean_score_time                                       0.000997305
# std_score_time                                        5.00111e-07
# param_C                                                     0.001
# param_gamma                                                 0.001
# param_kernel                                                  rbf
# params              {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# split0_test_score                                        0.333333
# split1_test_score                                        0.333333
# split2_test_score                                        0.352941
# split3_test_score                                          0.6875
# split4_test_score                                        0.333333
# mean_test_score                                          0.404762
# std_test_score                                           0.137361
# rank_test_score                                                27
# split0_train_score                                       0.348485
# split1_train_score                                       0.348485
# split2_train_score                                       0.343284
# split3_train_score                                       0.676471
# split4_train_score                                       0.347826
# mean_train_score                                          0.41291
# std_train_score                                          0.131795
#
#                                                               1   \
# mean_fit_time                                        0.000996971
# std_fit_time                                         7.77698e-07
# mean_score_time                                      0.000598955
# std_score_time                                       0.000489046
# param_C                                                    0.001
# param_gamma                                                 0.01
# param_kernel                                                 rbf
# params              {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# split0_test_score                                       0.333333
# split1_test_score                                       0.333333
# split2_test_score                                       0.352941
# split3_test_score                                         0.6875
# split4_test_score                                       0.333333
# mean_test_score                                         0.404762
# std_test_score                                          0.137361
# rank_test_score                                               27
# split0_train_score                                      0.348485
# split1_train_score                                      0.348485
# split2_train_score                                      0.343284
# split3_train_score                                      0.676471
# split4_train_score                                      0.347826
# mean_train_score                                         0.41291
# std_train_score                                         0.131795
#
#                                                              2   \
# mean_fit_time                                       0.000997877
# std_fit_time                                        7.16843e-07
# mean_score_time                                     0.000398922
# std_score_time                                      0.000488578
# param_C                                                   0.001
# param_gamma                                                 0.1
# param_kernel                                                rbf
# params              {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# split0_test_score                                      0.333333
# split1_test_score                                      0.333333
# split2_test_score                                      0.352941
# split3_test_score                                        0.6875
# split4_test_score                                      0.333333
# mean_test_score                                        0.404762
# std_test_score                                         0.137361
# rank_test_score                                              27
# split0_train_score                                     0.348485
# split1_train_score                                     0.348485
# split2_train_score                                     0.343284
# split3_train_score                                     0.676471
# split4_train_score                                     0.347826
# mean_train_score                                        0.41291
# std_train_score                                        0.131795
#
#                                                            3   \
# mean_fit_time                                      0.00130658
# std_fit_time                                      0.000880977
# mean_score_time                                   0.000199509
# std_score_time                                    0.000399017
# param_C                                                 0.001
# param_gamma                                                 1
# param_kernel                                              rbf
# params              {'C': 0.001, 'gamma': 1, 'kernel': 'rbf'}
# split0_test_score                                    0.333333
# split1_test_score                                    0.333333
# split2_test_score                                    0.352941
# split3_test_score                                      0.6875
# split4_test_score                                    0.333333
# mean_test_score                                      0.404762
# std_test_score                                       0.137361
# rank_test_score                                            27
# split0_train_score                                   0.348485
# split1_train_score                                   0.348485
# split2_train_score                                   0.343284
# split3_train_score                                   0.676471
# split4_train_score                                   0.347826
# mean_train_score                                      0.41291
# std_train_score                                      0.131795
#
#                                                             4   \
# mean_fit_time                                                0
# std_fit_time                                                 0
# mean_score_time                                              0
# std_score_time                                               0
# param_C                                                  0.001
# param_gamma                                                 10
# param_kernel                                               rbf
# params              {'C': 0.001, 'gamma': 10, 'kernel': 'rbf'}
# split0_test_score                                     0.333333
# split1_test_score                                     0.333333
# split2_test_score                                     0.352941
# split3_test_score                                          0.5
# split4_test_score                                     0.333333
# mean_test_score                                       0.369048
# std_test_score                                       0.0639789
# rank_test_score                                             37
# split0_train_score                                    0.348485
# split1_train_score                                    0.348485
# split2_train_score                                    0.343284
# split3_train_score                                    0.602941
# split4_train_score                                    0.347826
# mean_train_score                                      0.398204
# std_train_score                                       0.102387
#
#                                                              5   \
# mean_fit_time                                         0.0020133
# std_fit_time                                         0.00311663
# mean_score_time                                               0
# std_score_time                                                0
# param_C                                                   0.001
# param_gamma                                                 100
# param_kernel                                                rbf
# params              {'C': 0.001, 'gamma': 100, 'kernel': 'rbf'}
# split0_test_score                                      0.333333
# split1_test_score                                      0.333333
# split2_test_score                                      0.352941
# split3_test_score                                         0.375
# split4_test_score                                      0.333333
# mean_test_score                                        0.345238
# std_test_score                                        0.0163332
# rank_test_score                                              40
# split0_train_score                                     0.348485
# split1_train_score                                     0.348485
# split2_train_score                                     0.343284
# split3_train_score                                     0.676471
# split4_train_score                                     0.347826
# mean_train_score                                        0.41291
# std_train_score                                        0.131795
#
#                                                               6   \
# mean_fit_time                                                  0
# std_fit_time                                                   0
# mean_score_time                                                0
# std_score_time                                                 0
# param_C                                                     0.01
# param_gamma                                                0.001
# param_kernel                                                 rbf
# params              {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# split0_test_score                                       0.333333
# split1_test_score                                       0.333333
# split2_test_score                                       0.352941
# split3_test_score                                         0.6875
# split4_test_score                                       0.333333
# mean_test_score                                         0.404762
# std_test_score                                          0.137361
# rank_test_score                                               27
# split0_train_score                                      0.348485
# split1_train_score                                      0.348485
# split2_train_score                                      0.343284
# split3_train_score                                      0.676471
# split4_train_score                                      0.347826
# mean_train_score                                         0.41291
# std_train_score                                         0.131795
#
#                                                              7   \
# mean_fit_time                                        0.00160761
# std_fit_time                                         0.00321522
# mean_score_time                                               0
# std_score_time                                                0
# param_C                                                    0.01
# param_gamma                                                0.01
# param_kernel                                                rbf
# params              {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# split0_test_score                                      0.333333
# split1_test_score                                      0.333333
# split2_test_score                                      0.352941
# split3_test_score                                        0.6875
# split4_test_score                                      0.333333
# mean_test_score                                        0.404762
# std_test_score                                         0.137361
# rank_test_score                                              27
# split0_train_score                                     0.348485
# split1_train_score                                     0.348485
# split2_train_score                                     0.343284
# split3_train_score                                     0.676471
# split4_train_score                                     0.347826
# mean_train_score                                        0.41291
# std_train_score                                        0.131795
#
#                                                             8   \
# mean_fit_time                                                0
# std_fit_time                                                 0
# mean_score_time                                     0.00160913
# std_score_time                                      0.00321827
# param_C                                                   0.01
# param_gamma                                                0.1
# param_kernel                                               rbf
# params              {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# split0_test_score                                     0.333333
# split1_test_score                                     0.333333
# split2_test_score                                     0.352941
# split3_test_score                                       0.6875
# split4_test_score                                     0.333333
# mean_test_score                                       0.404762
# std_test_score                                        0.137361
# rank_test_score                                             27
# split0_train_score                                    0.348485
# split1_train_score                                    0.348485
# split2_train_score                                    0.343284
# split3_train_score                                    0.676471
# split4_train_score                                    0.347826
# mean_train_score                                       0.41291
# std_train_score                                       0.131795
#
#                                                           9   \
# mean_fit_time                                     0.00200715
# std_fit_time                                      0.00310611
# mean_score_time                                            0
# std_score_time                                             0
# param_C                                                 0.01
# param_gamma                                                1
# param_kernel                                             rbf
# params              {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}
# split0_test_score                                   0.333333
# split1_test_score                                   0.333333
# split2_test_score                                   0.352941
# split3_test_score                                     0.6875
# split4_test_score                                   0.333333
# mean_test_score                                     0.404762
# std_test_score                                      0.137361
# rank_test_score                                           27
# split0_train_score                                  0.348485
# split1_train_score                                  0.348485
# split2_train_score                                  0.343284
# split3_train_score                                  0.676471
# split4_train_score                                  0.347826
# mean_train_score                                     0.41291
# std_train_score                                     0.131795
#
#                                  ...                \
# mean_fit_time                    ...
# std_fit_time                     ...
# mean_score_time                  ...
# std_score_time                   ...
# param_C                          ...
# param_gamma                      ...
# param_kernel                     ...
# params                           ...
# split0_test_score                ...
# split1_test_score                ...
# split2_test_score                ...
# split3_test_score                ...
# split4_test_score                ...
# mean_test_score                  ...
# std_test_score                   ...
# rank_test_score                  ...
# split0_train_score               ...
# split1_train_score               ...
# split2_train_score               ...
# split3_train_score               ...
# split4_train_score               ...
# mean_train_score                 ...
# std_train_score                  ...
#
#                                                            32  \
# mean_fit_time                                               0
# std_fit_time                                                0
# mean_score_time                                             0
# std_score_time                                              0
# param_C                                                   100
# param_gamma                                               0.1
# param_kernel                                              rbf
# params              {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# split0_test_score                                    0.944444
# split1_test_score                                    0.944444
# split2_test_score                                    0.882353
# split3_test_score                                      0.9375
# split4_test_score                                    0.933333
# mean_test_score                                      0.928571
# std_test_score                                      0.0236544
# rank_test_score                                            12
# split0_train_score                                   0.969697
# split1_train_score                                   0.984848
# split2_train_score                                   0.985075
# split3_train_score                                   0.985294
# split4_train_score                                          1
# mean_train_score                                     0.984983
# std_train_score                                    0.00958432
#
#                                                          33  \
# mean_fit_time                                             0
# std_fit_time                                              0
# mean_score_time                                           0
# std_score_time                                            0
# param_C                                                 100
# param_gamma                                               1
# param_kernel                                            rbf
# params              {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# split0_test_score                                  0.944444
# split1_test_score                                  0.944444
# split2_test_score                                  0.882353
# split3_test_score                                    0.9375
# split4_test_score                                  0.933333
# mean_test_score                                    0.928571
# std_test_score                                    0.0236544
# rank_test_score                                          12
# split0_train_score                                        1
# split1_train_score                                        1
# split2_train_score                                        1
# split3_train_score                                        1
# split4_train_score                                        1
# mean_train_score                                          1
# std_train_score                                           0
#
#                                                           34  \
# mean_fit_time                                     0.00323009
# std_fit_time                                      0.00395604
# mean_score_time                                            0
# std_score_time                                             0
# param_C                                                  100
# param_gamma                                               10
# param_kernel                                             rbf
# params              {'C': 100, 'gamma': 10, 'kernel': 'rbf'}
# split0_test_score                                          1
# split1_test_score                                   0.833333
# split2_test_score                                   0.823529
# split3_test_score                                       0.75
# split4_test_score                                   0.933333
# mean_test_score                                     0.869048
# std_test_score                                     0.0883447
# rank_test_score                                           17
# split0_train_score                                         1
# split1_train_score                                         1
# split2_train_score                                         1
# split3_train_score                                         1
# split4_train_score                                         1
# mean_train_score                                           1
# std_train_score                                            0
#
#                                                            35  \
# mean_fit_time                                               0
# std_fit_time                                                0
# mean_score_time                                             0
# std_score_time                                              0
# param_C                                                   100
# param_gamma                                               100
# param_kernel                                              rbf
# params              {'C': 100, 'gamma': 100, 'kernel': 'rbf'}
# split0_test_score                                    0.666667
# split1_test_score                                    0.555556
# split2_test_score                                    0.470588
# split3_test_score                                         0.5
# split4_test_score                                    0.533333
# mean_test_score                                      0.547619
# std_test_score                                      0.0686998
# rank_test_score                                            24
# split0_train_score                                          1
# split1_train_score                                          1
# split2_train_score                                          1
# split3_train_score                                          1
# split4_train_score                                          1
# mean_train_score                                            1
# std_train_score                                             0
#
#                                                   36  \
# mean_fit_time                             0.00160079
# std_fit_time                              0.00320158
# mean_score_time                                    0
# std_score_time                                     0
# param_C                                        0.001
# param_gamma                                      NaN
# param_kernel                                  linear
# params              {'C': 0.001, 'kernel': 'linear'}
# split0_test_score                           0.333333
# split1_test_score                           0.333333
# split2_test_score                           0.352941
# split3_test_score                             0.6875
# split4_test_score                           0.333333
# mean_test_score                             0.404762
# std_test_score                              0.137361
# rank_test_score                                   27
# split0_train_score                          0.348485
# split1_train_score                          0.348485
# split2_train_score                          0.343284
# split3_train_score                          0.676471
# split4_train_score                          0.347826
# mean_train_score                             0.41291
# std_train_score                             0.131795
#
#                                                  37  \
# mean_fit_time                            0.00161395
# std_fit_time                              0.0032279
# mean_score_time                         0.000412321
# std_score_time                          0.000824642
# param_C                                        0.01
# param_gamma                                     NaN
# param_kernel                                 linear
# params              {'C': 0.01, 'kernel': 'linear'}
# split0_test_score                          0.777778
# split1_test_score                          0.777778
# split2_test_score                          0.764706
# split3_test_score                             0.875
# split4_test_score                               0.8
# mean_test_score                            0.797619
# std_test_score                            0.0391088
# rank_test_score                                  21
# split0_train_score                         0.833333
# split1_train_score                         0.787879
# split2_train_score                         0.820896
# split3_train_score                         0.838235
# split4_train_score                         0.782609
# mean_train_score                            0.81259
# std_train_score                           0.0230932
#
#                                                 38  \
# mean_fit_time                                    0
# std_fit_time                                     0
# mean_score_time                         0.00200977
# std_score_time                          0.00310796
# param_C                                        0.1
# param_gamma                                    NaN
# param_kernel                                linear
# params              {'C': 0.1, 'kernel': 'linear'}
# split0_test_score                         0.944444
# split1_test_score                         0.944444
# split2_test_score                         0.941176
# split3_test_score                           0.9375
# split4_test_score                                1
# mean_test_score                           0.952381
# std_test_score                           0.0223496
# rank_test_score                                  6
# split0_train_score                        0.954545
# split1_train_score                        0.969697
# split2_train_score                        0.970149
# split3_train_score                        0.970588
# split4_train_score                        0.956522
# mean_train_score                            0.9643
# std_train_score                         0.00719076
#
#                                               39  \
# mean_fit_time                                  0
# std_fit_time                                   0
# mean_score_time                                0
# std_score_time                                 0
# param_C                                        1
# param_gamma                                  NaN
# param_kernel                              linear
# params              {'C': 1, 'kernel': 'linear'}
# split0_test_score                              1
# split1_test_score                              1
# split2_test_score                       0.941176
# split3_test_score                              1
# split4_test_score                       0.933333
# mean_test_score                          0.97619
# std_test_score                         0.0304473
# rank_test_score                                2
# split0_train_score                      0.969697
# split1_train_score                             1
# split2_train_score                      0.985075
# split3_train_score                      0.985294
# split4_train_score                      0.985507
# mean_train_score                        0.985115
# std_train_score                        0.0095861
#
#                                                40  \
# mean_fit_time                          0.00160599
# std_fit_time                           0.00321198
# mean_score_time                       0.000404167
# std_score_time                        0.000808334
# param_C                                        10
# param_gamma                                   NaN
# param_kernel                               linear
# params              {'C': 10, 'kernel': 'linear'}
# split0_test_score                               1
# split1_test_score                        0.944444
# split2_test_score                        0.882353
# split3_test_score                          0.9375
# split4_test_score                        0.933333
# mean_test_score                          0.940476
# std_test_score                          0.0381721
# rank_test_score                                 8
# split0_train_score                       0.969697
# split1_train_score                       0.984848
# split2_train_score                       0.985075
# split3_train_score                       0.985294
# split4_train_score                              1
# mean_train_score                         0.984983
# std_train_score                        0.00958432
#
#                                                 41
# mean_fit_time                                    0
# std_fit_time                                     0
# mean_score_time                                  0
# std_score_time                                   0
# param_C                                        100
# param_gamma                                    NaN
# param_kernel                                linear
# params              {'C': 100, 'kernel': 'linear'}
# split0_test_score                         0.944444
# split1_test_score                         0.944444
# split2_test_score                         0.941176
# split3_test_score                           0.9375
# split4_test_score                         0.933333
# mean_test_score                           0.940476
# std_test_score                          0.00420071
# rank_test_score                                  8
# split0_train_score                        0.984848
# split1_train_score                        0.984848
# split2_train_score                        0.985075
# split3_train_score                               1
# split4_train_score                               1
# mean_train_score                          0.990954
# std_train_score                         0.00738623
#
# [23 rows x 42 columns]
